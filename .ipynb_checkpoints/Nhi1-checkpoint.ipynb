# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON

# Data viz packages
import seaborn as sns
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import numpy as np

# %%
from datetime import datetime, timedelta
from apiclient.discovery import build

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
# NLP
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nhidang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/nhidang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import sys
print(sys.executable)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9

# %%
api_key = 'AIzaSyDtn4B5PAcHBwWkRhTWmj9OQ5ncEbY8IWk'

# %%
channel_ids = ['UCoOae5nYA7VqaXzerajD0lg',]

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client

youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    all_data = []

    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()
    
    #loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
               'subscribers': item ['statistics']['subscriberCount'],
               'views': item ['statistics']['viewCount'],
               'totalVideo': item ['statistics']['videoCount'],
               'playlistId': item ['contentDetails']['relatedPlaylists']['uploads']}
        
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#   channelName subscribers      views totalVideo                playlistId
# 0  Ali Abdaal     2780000  183868974        435  UUoOae5nYA7VqaXzerajD0lg

# %%
playlist_id = "UUoOae5nYA7VqaXzerajD0lg"

def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)

# %%
video_df
# Out:
#         video_id channelTitle  \
# 0    XpopyNZKYKw   Ali Abdaal
# 1    06aaT3kZdkE   Ali Abdaal
# 2    76yqErAib5g   Ali Abdaal
# 3    4V2ZwgJw62I   Ali Abdaal
# 4    pPKJ_Pk9zZs   Ali Abdaal
# ..           ...          ...
# 430  7APfFjfnNBc   Ali Abdaal
# 431  gBpBLTSCb4s   Ali Abdaal
# 432  Va0tSdPADpA   Ali Abdaal
# 433  XJHM0fEH3ss   Ali Abdaal
# 434  LQ3Mu8A7gjY   Ali Abdaal
#
#                                                  title  \
# 0    How To Start a YouTube Channel - Beginner’s Gu...
# 1                    Money Mistakes I Made in My Teens
# 2    How I Ranked 1st at Cambridge University - 20 ...
# 3                 7 Side Hustles You Can Start in 2022
# 4      What's in my Bag 2022 - Budget, Premium, Luxury
# ..                                                 ...
# 430  Payphone (Maroon 5) - Katherine Macfarland & A...
# 431            6med UKCAT Crash Course - In a Nutshell
# 432             6med BMAT Crash Course - In a Nutshell
# 433  Rolling in the Deep (Adele) - Duranka Perera &...
# 434           All of Me (John Legend) - Duranka Perera
#
#                                            description  \
# 0    PART-TIME YOUTUBER ACADEMY:\n🍿 My 6-week live ...
# 1    The first 1,000 people to use this link will g...
# 2    To improve your thinking and learn new skills,...
# 3    Sign up to Curiosity Stream to watch the delet...
# 4    Rize is the only time tracker that I use to he...
# ..                                                 ...
# 430  First cover of 2017! We both love this song, s...
# 431  The 6med UKCAT Crash Course is the most effect...
# 432  The 6med BMAT Crash Course is the most effecti...
# 433  Our first 'proper' video! One of our all-time ...
# 434  First attempt at playing around with this sort...
#
#                                                   tags           publishedAt  \
# 0    [Ali Abdaal, Ali abdal, how to start a youtube...  2022-03-03T14:12:58Z
# 1    [Ali Abdaal, Ali abdal, money mistakes to avoi...  2022-02-28T15:56:00Z
# 2    [Ali Abdaal, Ali abdal, How I Ranked 1st at Ca...  2022-02-23T17:39:05Z
# 3    [Ali Abdaal, Ali abdal, passive income, how to...  2022-02-16T13:53:16Z
# 4    [Ali Abdaal, Ali abdal, What's in my Bag 2022,...  2022-02-10T15:15:03Z
# ..                                                 ...                   ...
# 430        [payphone, maroon 5, acoustic cover, cover]  2017-01-04T23:13:51Z
# 431            ed, medical school, ukcat, medicine]  2016-05-09T18:45:18Z
# 432           [BMAT, 6med, medicine, medical students]  2016-04-27T09:04:49Z
# 433      [rolling in the deep, adele, cover, acoustic]  2016-04-05T09:05:29Z
# 434                                               None  2016-03-27T19:30:11Z
#
#     viewCount likeCount favouriteCount commentCount  duration definition  \
# 0      169880     10386           None         1228   PT32M6S         hd
# 1      122433      6747           None          576  PT16M51S         hd
# 2      290756     15858           None          839  PT22M11S         hd
# 3      494004     23075           None         2120  PT22M33S         hd
# 4      193742      6467           None          741     PT14M         hd
# ..        ...       ...            ...          ...       ...        ...
# 430     67548      1780           None          107   PT2M35S         hd
# 431     12077        87           None            4   PT2M11S         hd
# 432     30484       231           None            8   PT2M18S         hd
# 433     41003       520           None           25   PT2M29S         hd
# 434     82222      1038           None          104   PT1M43S         hd
#
#     caption
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ..      ...
# 430   false
# 431   false
# 432   false
# 433   false
# 434   false
#
# [435 rows x 13 columns]

# %%
##Data pre-processing

# %%
# Check for NULL values
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
#Check data types
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
# Convert count columns to numeric
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
#Convert pushlishAt to datetime
datetime_cols = ['publishedAt']
video_df[datetime_cols] = video_df[datetime_cols].apply(pd.to_datetime)

# %%
# Publish day in the week
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A")) ##QUESTION

# %%
from datetime import datetime

# %%
from dateutil import parser
#yourdate = parser.parse(datetime)

# %%
import argparse
parser = argparse.ArgumentParser()

# %%
args, unknown = parser.parse_known_args()

# %%
# convert duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs', 'duration']]
# Out:
#      durationSecs  duration
# 0          1926.0   PT32M6S
# 1          1011.0  PT16M51S
# 2          1331.0  PT22M11S
# 3          1353.0  PT22M33S
# 4           840.0     PT14M
# ..            ...       ...
# 430         155.0   PT2M35S
# 431         131.0   PT2M11S
# 432         138.0   PT2M18S
# 433         149.0   PT2M29S
# 434         103.0   PT1M43S
#
# [435 rows x 2 columns]

# %%
# Add tag count
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#         video_id channelTitle  \
# 0    XpopyNZKYKw   Ali Abdaal
# 1    06aaT3kZdkE   Ali Abdaal
# 2    76yqErAib5g   Ali Abdaal
# 3    4V2ZwgJw62I   Ali Abdaal
# 4    pPKJ_Pk9zZs   Ali Abdaal
# ..           ...          ...
# 430  7APfFjfnNBc   Ali Abdaal
# 431  gBpBLTSCb4s   Ali Abdaal
# 432  Va0tSdPADpA   Ali Abdaal
# 433  XJHM0fEH3ss   Ali Abdaal
# 434  LQ3Mu8A7gjY   Ali Abdaal
#
#                                                  title  \
# 0    How To Start a YouTube Channel - Beginner’s Gu...
# 1                    Money Mistakes I Made in My Teens
# 2    How I Ranked 1st at Cambridge University - 20 ...
# 3                 7 Side Hustles You Can Start in 2022
# 4      What's in my Bag 2022 - Budget, Premium, Luxury
# ..                                                 ...
# 430  Payphone (Maroon 5) - Katherine Macfarland & A...
# 431            6med UKCAT Crash Course - In a Nutshell
# 432             6med BMAT Crash Course - In a Nutshell
# 433  Rolling in the Deep (Adele) - Duranka Perera &...
# 434           All of Me (John Legend) - Duranka Perera
#
#                                            description  \
# 0    PART-TIME YOUTUBER ACADEMY:\n🍿 My 6-week live ...
# 1    The first 1,000 people to use this link will g...
# 2    To improve your thinking and learn new skills,...
# 3    Sign up to Curiosity Stream to watch the delet...
# 4    Rize is the only time tracker that I use to he...
# ..                                                 ...
# 430  First cover of 2017! We both love this song, s...
# 431  The 6med UKCAT Crash Course is the most effect...
# 432  The 6med BMAT Crash Course is the most effecti...
# 433  Our first 'proper' video! One of our all-time ...
# 434  First attempt at playing around with this sort...
#
#                                                   tags  \
# 0    [Ali Abdaal, Ali abdal, how to start a youtube...
# 1    [Ali Abdaal, Ali abdal, money mistakes to avoi...
# 2    [Ali Abdaal, Ali abdal, How I Ranked 1st at Ca...
# 3    [Ali Abdaal, Ali abdal, passive income, how to...
# 4    [Ali Abdaal, Ali abdal, What's in my Bag 2022,...
# ..                                                 ...
# 430        [payphone, maroon 5, acoustic cover, cover]
# 431            ed, medical school, ukcat, medicine]
# 432           [BMAT, 6med, medicine, medical students]
# 433      [rolling in the deep, adele, cover, acoustic]
# 434                                               None
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2022-03-03 14:12:58+00:00   169880.0    10386.0             NaN
# 1   2022-02-28 15:56:00+00:00   122433.0     6747.0             NaN
# 2   2022-02-23 17:39:05+00:00   290756.0    15858.0             NaN
# 3   2022-02-16 13:53:16+00:00   494004.0    23075.0             NaN
# 4   2022-02-10 15:15:03+00:00   193742.0     6467.0             NaN
# ..                        ...        ...        ...             ...
# 430 2017-01-04 23:13:51+00:00    67548.0     1780.0             NaN
# 431 2016-05-09 18:45:18+00:00    12077.0       87.0             NaN
# 432 2016-04-27 09:04:49+00:00    30484.0      231.0             NaN
# 433 2016-04-05 09:05:29+00:00    41003.0      520.0             NaN
# 434 2016-03-27 19:30:11+00:00    82222.0     1038.0             NaN
#
#      commentCount  duration definition caption pushblishDayName  durationSecs  \
# 0          1228.0   PT32M6S         hd   false         Thursday        1926.0
# 1           576.0  PT16M51S         hd   false           Monday        1011.0
# 2           839.0  PT22M11S         hd   false        Wednesday        1331.0
# 3          2120.0  PT22M33S         hd   false        Wednesday        1353.0
# 4           741.0     PT14M         hd   false         Thursday         840.0
# ..            ...       ...        ...     ...              ...           ...
# 430         107.0   PT2M35S         hd   false        Wednesday         155.0
# 431           4.0   PT2M11S         hd   false           Monday         131.0
# 432           8.0   PT2M18S         hd   false        Wednesday         138.0
# 433          25.0   PT2M29S         hd   false          Tuesday         149.0
# 434         104.0   PT1M43S         hd   false           Sunday         103.0
#
#      tagCount
# 0          15
# 1          15
# 2          25
# 3          21
# 4          23
# ..        ...
# 430         4
# 431         4
# 432         4
# 433         4
# 434         0
#
# [435 rows x 16 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# **Best performing videos**

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(tick.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# **Worst performing video**

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:15])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(tick.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# **View distribution per video**

# %%
sns.violinplot(video_df['channelTitle'], video_df['viewCount'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>

# %% [markdown]
# **Views vs like and comments**

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %% [markdown]
# **Video duration**

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins=30)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>

# %% [markdown]
# **Update Schedule**

# %%
day_df = pd.DataFrame(video_df['pushblishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='pushblishDayName', rot=0)

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins=30)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>

# %% [markdown]
# **Upload Schedule (Weekdays)**

# %%
day_df = pd.DataFrame(video_df['pushblishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='pushblishDayName', rot=45)

# %% [markdown]
# **Wordcloud For Video Titles**

# %%
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)
